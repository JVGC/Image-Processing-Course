# %%
import numpy as np
import imageio
import skimage
import matplotlib.pyplot as plt
from skimage import morphology

# %%
filename = str(input()).rstrip()
k = int(input())
option = int(input())
# Out:
# pencil.png
# 2
# 2

# %%
input_image =  imageio.imread('./images/'+filename)
plt.imshow(input_image)

# %%
output_image = opening(input_image, 2*k)
